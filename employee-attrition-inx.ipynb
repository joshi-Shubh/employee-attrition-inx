# %% [markdown]
# # Employee Performance Analytics for INX Future Inc

# %% [markdown]
# ## Business Case :-
# > *  INX Future Inc. is facing a decline in employee performance and an 8% drop in client satisfaction, despite a strong reputation as a top employer. Management is hesitant to penalize underperformers due to potential morale and branding impacts.
#
# > *  To address this, INX is launching a data science project to analyze employee data, identify performance issues, and uncover key drivers of underperformance. The goal is to enable targeted interventions that improve productivity without harming employee morale or employer branding.
#
# > *  By leveraging data analytics and predictive modeling, the company can make informed, precise decisions—enhancing service quality, retaining top talent, and restoring client satisfaction.

# %% [markdown]
# ### Data Understanding  :-

# %% [markdown]
# > * The dataset consists of 1200 employee records and 28 features that provide demographic, job-related, and performance information of employees. This section outlines the structure, types, and completeness of the data.
#
# ##### Dataset Overview
# > * Rows (Samples): 1200
# > * Columns (Features): 28
# > * Target Variable: Attrition (Yes/No)

# %% [markdown]
# ###  Feature Descriptions
#
# | **Feature Name**                     | **Description** |
# |-------------------------------------|-----------------|
# | `EmpNumber`                         | Unique employee identifier |
# | `Age`                               | Age of the employee |
# | `Gender`                            | Gender (Male/Female) |
# | `EducationBackground`              | Field of education (e.g., Marketing, Life Sciences) |
# | `MaritalStatus`                    | Marital status (Single, Married, Divorced) |
# | `EmpDepartment`                    | Department (e.g., Sales, R&D) |
# | `EmpJobRole`                       | Specific job title |
# | `BusinessTravelFrequency`         | Frequency of business travel |
# | `DistanceFromHome`                | Distance from employee’s home to work |
# | `EmpEducationLevel`               | Education level (1–5) |
# | `EmpEnvironmentSatisfaction`      | Satisfaction with the work environment |
# | `EmpHourlyRate`                   | Hourly wage rate |
# | `EmpJobInvolvement`               | Level of job involvement |
# | `EmpJobLevel`                     | Level within the job hierarchy |
# | `EmpJobSatisfaction`              | Satisfaction with job |
# | `NumCompaniesWorked`              | Number of companies the employee has worked for |
# | `OverTime`                        | Whether employee works overtime (Yes/No) |
# | `EmpLastSalaryHikePercent`        | Last salary hike in percentage |
# | `EmpRelationshipSatisfaction`     | Satisfaction with personal relationships at work |
# | `TotalWorkExperienceInYears`      | Total years of experience |
# | `TrainingTimesLastYear`           | Number of training sessions last year |
# | `EmpWorkLifeBalance`              | Work-life balance rating |
# | `ExperienceYearsAtThisCompany`    | Years of experience at the current company |
# | `ExperienceYearsInCurrentRole`    | Year

# %%
import pandas as pd        # For data handling
import numpy as np         # For numerical operations
import matplotlib.pyplot as plt  # For plotting
import seaborn as sns      # For advanced visualizations
import warnings
warnings.filterwarnings('ignore')  # Ignore warnings

# %%
data = pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')  # Load Excel data into a DataFrame

# %%
data # See Data
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
pd.set_option('display.max_columns', None)  # Show all columns when displaying the DataFrame

# %%
data # See full column wise data
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %% [markdown]
# # Basic Check:-

# %%
data.head() # See first 5 data
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %%
data.tail() # see last 5 data
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# ...

# %%
data.info()  # Display summary of the DataFrame including column names, non-null counts, and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
data.describe()  # Generate summary statistics for numerical columns
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
data.duplicated().sum()  # Count the number of duplicate rows in the DataFrame
# Out:
# 0

# %%
data.isnull().sum()  # Count missing (null) values in each column
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
data.describe(include="O")
# Out:
#        EmpNumber Gender EducationBackground MaritalStatus EmpDepartment  \
# count       1200   1200                1200          1200          1200
# unique      1200      2                   6             3             6
# top     E1001000   Male       Life Sciences       Married         Sales
# freq           1    725                 492           548           373
#
#              EmpJobRole BusinessTravelFrequency OverTime Attrition
# count              1200                    1200     1200      1200
# unique               19                       3        2         2
# top     Sales Executive           Travel_Rarely       No        No
# freq                270                     846      847      1022

# %%
cat_col = data.select_dtypes(include='object')  # Select all categorical (object type) columns

# %%
cat_col  # Display the DataFrame containing only categorical columns
# Out:
#      EmpNumber  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0     E1001000    Male           Marketing        Single            Sales
# 1     E1001006    Male           Marketing        Single            Sales
# 2     E1001007    Male       Life Sciences       Married            Sales
# 3     E1001009    Male     Human Resources      Divorced  Human Resources
# 4     E1001010    Male           Marketing        Single            Sales
# ...        ...     ...                 ...           ...              ...
# 1195   E100992  Female             Medical      Divorced            Sales
# 1196   E100993    Male       Life Sciences        Single      Development
# 1197   E100994    Male             Medical       Married      Development
# 1198   E100995  Female             Medical        Single     Data Science
# 1199   E100998  Female       Life Sciences        Single            Sales
#
#             EmpJobRole BusinessTravelFrequency OverTime Attrition
# ...

# %%
data.drop('EmpNumber', axis=1, inplace=True)  # Remove 'EmpNumber' column from the DataFrame

# %%
num_col = data.select_dtypes(include='int')  # Select all integer-type numerical columns

# %%
num_col  # Display the DataFrame containing only integer columns
# Out:
#       Age  DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0      32                10                  3                           4
# 1      47                14                  4                           4
# 2      40                 5                  4                           4
# 3      41                10                  4                           2
# 4      60                16                  4                           1
# ...   ...               ...                ...                         ...
# 1195   27                 3                  1                           4
# 1196   37                10                  2                           4
# 1197   50                28                  1                           4
# 1198   34                 9                  3                           4
# 1199   24                 3                  2                           1
#
# ...

# %% [markdown]
# ## EDA:- Exploratory Data Analysis

# %%
#  Department-wise average performance
dept_performance = data.groupby("EmpDepartment")["PerformanceRating"].mean().sort_values(ascending=False)
print("Department-wise Average Performance:\n", dept_performance)
# Out:
# Department-wise Average Performance:
#  EmpDepartment
# Development               3.085873
# Data Science              3.050000
# Human Resources           2.925926
# Research & Development    2.921283
# Sales                     2.860590
# Finance                   2.775510
# Name: PerformanceRating, dtype: float64

# %%
# Average performance per department
dept_perf = data.groupby("EmpDepartment")["PerformanceRating"].mean().sort_values(ascending=False)
dept_perf.plot(kind='bar', figsize=(10, 6), title='Average Performance by Department')
plt.ylabel('Avg Performance Rating')
plt.xlabel('Department')
plt.show()

# %%
#  Top 3 important factors affecting performance
numeric_cols = data.select_dtypes(include='number')
correlation_with_perf = numeric_cols.corr()["PerformanceRating"].sort_values(key=abs, ascending=False)

# %%
# Correlation of all numeric features with performance rating
corr = data.select_dtypes(include='number').corr()
correlation_with_perf = corr["PerformanceRating"].sort_values(ascending=False)
top_3 = correlation_with_perf.drop("PerformanceRating").head(3)

print("Top 3 correlated features with performance:")
print(top_3)
# Out:
# Top 3 correlated features with performance:
# EmpEnvironmentSatisfaction    0.395561
# EmpLastSalaryHikePercent      0.333722
# EmpWorkLifeBalance            0.124429
# Name: PerformanceRating, dtype: float64

# %% [markdown]
# ## 1. Univarinat Analysis

# %%
plt.figure(figsize=(20, 25))  # Set figure size for the plots
num = 1  # Initialize subplot counter

for i in cat_col:  # Loop through each categorical column
    plt.subplot(3, 3, num)  # Create a subplot in a 3x3 grid
    
    if i == 'EmpNumber':  # Skip 'EmpNumber' column
        continue
    
    if data[i].nunique() < 10:  # Only plot if unique values less than 10 (categorical)
        # sns.histplot(data=data[i], kde=True, color='skyblue')  # Histogram with KDE
        sns.countplot(data=data, x=i, palette='viridis')  # Countplot overlay
    else:
        continue  # Skip columns with too many unique values
    
    plt.title(f'Distribution of {i}')  # Set plot title
    plt.xlabel(i)  # Set x-axis label
    plt.ylabel('Count')  # Set y-axis label

    num += 1  # Increment subplot counter

plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()  # Display the plots

# %% [markdown]
# # 📊 Categorical Variable Distribution & Insights
#
# This section presents the distribution of key categorical features in the dataset. The visualized bar plots help analyze employee profiles and behaviors, enabling informed decision-making for predicting attrition and improving workforce management.
#
# ---
#
# ## 1. Gender Distribution
#
# **Observation:**
# - Male: ~730
# - Female: ~470
#
# **Insight:**
# There is a clear gender imbalance in the dataset, with more male employees than female. Gender should be considered during analysis, especially for fairness and diversity-related insights.
#
# ---
#
# ## 2. Education Background
#
# **Observation:**
# - Highest: Life Sciences (~490), Medical (~380)
# - Moderate: Marketing (~140), Technical Degree (~100)
# - Lowest: Human Resources and Other (<50)
#
# **Insight:**
# Most employees have a background in Life Sciences and Medical fields, suggesting the company may be healthcare, pharma, or R&D oriented. This background may influence department placement and attrition behavior.
#
# ---
#
# ## 3. Marital Status
#
# **Observation:**
# - Married: ~530
# - Single: ~370
# - Divorced: ~250
#
# **Insight:**
# Married employees form the majority, followed by single and divorced individuals. This demographic detail might affect overtime willingness and attrition, especially when considered with other variables like age and job role.
#
# ---
#
# ## 4. Employee Department
#
# **Observation:**
# - Highest: Research & Development (~350)
# - Moderate: Sales (~350)
# - Low: Human Resources (~50), Technical (~50), Others (<50)
#
# **Insight:**
# The workforce is mainly concentrated in **Research & Development** and **Sales**, reflecting the organization’s core operational areas. Attrition prediction models should account for departmental influence.
#
# ---
#
# ## 5. Business Travel Frequency
#
# **Observation:**
# - Travel_Rarely: ~850
# - Travel_Frequently: ~220
# - Non-Travel: ~130
#
# **Insight:**
# Most employees travel infrequently. Frequent travel could contribute to higher stress and job dissatisfaction, making it a potential predictor of attrition.
#
# ---
#
# ## 6. OverTime
#
# **Observation:**
# - No: ~850
# - Yes: ~350
#
# **Insight:**
# A substantial number of employees work overtime. Overtime is a known factor that increases burnout, and it could strongly correlate with attrition or performance degradation.
#
# ---
#
# ## 7. Attrition
#
# **Observation:**
# - No: ~1000
# - Yes: ~200
#
# **Insight:**
# The dataset shows **class imbalance** with far more employees staying than leaving. This imbalance should be addressed during model training using techniques like resampling, SMOTE, or class weights to ensure accurate predictions.
#
# ---

# %%
plt.figure(figsize=(20, 25))  # Set figure size
num = 1  # Initialize subplot counter

for i in num_col:  # Loop over numerical columns
    plt.subplot(4, 5, num)  # Create subplot in a 4x5 grid
    sns.histplot(data=data[i], kde=True, color='skyblue')  # Plot histogram with KDE
    plt.title(f'Distribution of {i}')  # Set title with column name
    plt.xlabel(i)  # Set x-axis label to column name (fixed from 'i')
    plt.ylabel('Distribution')  # Set y-axis label
    num += 1  # Increment subplot number

plt.tight_layout()  # Adjust subplot spacing
plt.show()  # Show the plots

# %% [markdown]
# # Numerical Variable Distribution & Insights
#
# This section analyzes the distribution of continuous variables in the dataset. Understanding the spread and patterns of these features helps detect skewness, outliers, and data imbalances that can impact attrition modeling.
#
# ---
#
# ## 1. Age
# **Observation:** Peaks around 30-35 years
# **Insight:** The workforce is relatively young, with most employees aged between 25 and 40. Age might be an important factor in attrition modeling.
#
# ---
#
# ## 2. Distance From Home
# **Observation:** Right-skewed; most employees live within 10 km
# **Insight:** Long commute distances are rare. Employees living farther may experience higher stress, possibly contributing to attrition.
#
# ---
#
# ## 3. Education Level
# **Observation:** Mode is 3 (Bachelor’s); range 1–5
# **Insight:** Majority of employees have moderate to high education. Higher education might correlate with expectations around growth and compensation.
#
# ---
#
# ## 4. Environment Satisfaction
# **Observation:** Uniformly distributed across levels 1 to 4
# **Insight:** Employee satisfaction with the environment varies. Further analysis could reveal its impact on attrition.
#
# ---
#
# ## 5. Hourly Rate
# **Observation:** Nearly uniform across the range 40–100
# **Insight:** No strong concentration at any particular rate; may indicate differentiated pay structures across departments.
#
# ---
#
# ## 6. Job Involvement
# **Observation:** Most employees are rated 3 (Moderate)
# **Insight:** Majority feel moderately involved. Lower or higher involvement levels may correlate with attrition risk.
#
# ---
#
# ## 7. Job Level
# **Observation:** Skewed towards lower levels (1 and 2 dominate)
# **Insight:** Junior staff dominate the workforce. These levels might experience higher attrition due to career transitions.
#
# ---
#
# ## 8. Job Satisfaction
# **Observation:** Multiple peaks (mostly 3 and 4)
# **Insight:** Satisfaction is generally high, but those with lower satisfaction levels should be analyzed for attrition risk.
#
# ---
#
# ## 9. Number of Companies Worked
# **Observation:** Most have worked at 1–3 companies
# **Insight:** Job-hopping is limited, suggesting some employee stability. Those with more transitions may be prone to churn.
#
# ---
#
# ## 10. Percent Salary Hike
# **Observation:** Most receive between 11%–15% hikes
# **Insight:** Standardized increments could affect motivation and loyalty. Higher variation might reduce attrition.
#
# ---
#
# ## 11. Relationship Satisfaction
# **Observation:** Spread across all satisfaction levels
# **Insight:** May impact morale and performance. Needs correlation with other job satisfaction metrics.
#
# ---
#
# ## 12. Total Work Experience
# **Observation:** Right-skewed; mode around 10 years
# **Insight:** Workforce is moderately experienced. Those with more experience may have higher expectations or risk of attrition.
#
# ---
#
# ## 13. Training Times Last Year
# **Observation:** Peaks at 2–3 trainings
# **Insight:** Most employees receive 2–3 training sessions annually. Low training frequency may signal limited growth opportunities.
#
# ---
#
# ## 14. Work-Life Balance
# **Observation:** Peaks at level 3 (Good)
# **Insight:** Generally good work-life balance, though some report low ratings. Could influence attrition and engagement.
#
# ---
#
# ## 15. Years at Company
# **Observation:** Highly right-skewed; most under 10 years
# **Insight:** Most employees are relatively new. A steep drop-off may suggest early-stage attrition risks.
#
# ---
#
# ## 16. Years in Current Role
# **Observation:** Peaks between 2–5 years
# **Insight:** Indicates average tenure in roles. Long stagnation might lead to dissatisfaction.
#
# ---
#
# ## 17. Years Since Last Promotion
# **Observation:** Most are promoted within 0–3 years
# **Insight:** Recent promotions dominate. Long gaps might result in disengagement or exits.
#
# ---
#
# ## 18. Years With Current Manager
# **Observation:** Peaks around 2 years
# **Insight:** Employee-manager relationships are relatively recent. A strong bond or lack of one may influence retention.
#
# ---
#
# ## 19. Performance Rating
# **Observation:** Nearly all are rated 3 (Good)
# **Insight:** Minimal variance in ratings could reduce motivation for top performers. Limited differentiation may affect retention strategies.
#
# ---

# %% [markdown]
# ## Feature Engineering
#
# > * Feature engineering is an essential step in the data preprocessing process. By leveraging domain knowledge and creativity, you can transform raw data into meaningful features that enhance the performance of machine learning models. Creating new features or modifying existing ones can help the model capture more relevant patterns and relationships, ultimately improving its ability to make accurate predictions.

# %% [markdown]
# #### Encoding Categorical Variables : Categorical variables need to be transformed into numerical formats for machine learning models.
#
# * Label Encoding
# * One-Hot Encoding
# * Ordinal Encoding

# %%
from sklearn.preprocessing import LabelEncoder  # Import LabelEncoder for encoding categorical variables

# %%
LE = LabelEncoder()  # Create an instance of LabelEncoder

# %%
cat_col = data.select_dtypes(include='object')  # Select all categorical columns from data

# %%
for i in cat_col:  
    data[i] = LE.fit_transform(data[i])  # Encode each categorical column into numeric labels

# %%
data
# Out:
#       Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 0      32       1                    2              2              5
# 1      47       1                    2              2              5
# 2      40       1                    1              1              5
# 3      41       1                    0              0              3
# 4      60       1                    2              2              5
# ...   ...     ...                  ...            ...            ...
# 1195   27       0                    3              0              5
# 1196   37       1                    1              2              1
# 1197   50       1                    3              1              1
# 1198   34       0                    3              2              0
# 1199   24       0                    1              2              5
#
#       EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0             13                        2                10
# ...

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# * Data Preprocessing : It is cleaning, transforming, and organizing the data into a suitable structure.

# %%
plt.figure(figsize=(20, 25))  # Set the figure size
num = 1  # Initialize subplot counter

for col in data.columns:  # Loop through all columns
    plt.subplot(5, 6, num)  # Create subplot in a 5x6 grid
    sns.boxplot(data=data, x=col)  # Draw boxplot for the column
    num += 1  # Increment subplot counter

plt.tight_layout()  # Adjust subplot spacing to avoid overlap
plt.show()  # Display all the boxplots

# %%
data.loc[data['NumCompaniesWorked'] > 8 , 'NumCompaniesWorked']
# Out:
# 8       9
# 11      9
# 16      9
# 38      9
# 56      9
# 73      9
# 105     9
# 149     9
# 184     9
# 211     9
# 231     9
# 251     9
# 321     9
# 338     9
# 343     9
# 409     9
# 476     9
# 497     9
# 553     9
# 588     9
# 664     9
# 740     9
# 766     9
# 793     9
# 804     9
# 925     9
# 929     9
# 939     9
# 967     9
# 1003    9
# 1006    9
# 1042    9
# 1069    9
# 1070    9
# 1082    9
# 1130    9
# 1137    9
# 1143    9
# 1199    9
# Name: NumCompaniesWorked, dtype: int64

# %%
len(data.loc[data['NumCompaniesWorked'] > 8 , 'NumCompaniesWorked'])
# Out:
# 39

# %%
data.NumCompaniesWorked.mode()
# Out:
# 0    1
# Name: NumCompaniesWorked, dtype: int64

# %%
data.loc[data['NumCompaniesWorked'] > 8 , 'NumCompaniesWorked'] = 1

# %%
data.TotalWorkExperienceInYears.median()
# Out:
# 10.0

# %%
data.loc[data['TotalWorkExperienceInYears'] > 28 , 'TotalWorkExperienceInYears']
# Out:
# 17      30
# 25      34
# 48      30
# 72      29
# 77      35
# 96      33
# 100     31
# 149     32
# 173     30
# 178     33
# 192     29
# 199     31
# 277     32
# 292     33
# 295     36
# 308     34
# 312     31
# 342     36
# 347     33
# 351     31
# 356     29
# 361     33
# 387     29
# 388     32
# 424     29
# 450     32
# 471     34
# 475     36
# 490     32
# 525     30
# 528     36
# 589     34
# 615     37
# 642     29
# 678     29
# 703     35
# 777     31
# 816     29
# 845     38
# 867     40
# 921     34
# 958     32
# 962     33
# 989     37
# 1077    30
# 1101    31
# 1104    33
# 1116    32
# 1135    37
# 1156    31
# 1160    32
# Name: TotalWorkExperienceInYears, dtype: int64

# %%
data.loc[data['TotalWorkExperienceInYears'] > 28 , 'TotalWorkExperienceInYears'] = 10

# %%
data.TrainingTimesLastYear.median()
# Out:
# 3.0

# %%
data.loc[data['TrainingTimesLastYear'] <1 , 'TrainingTimesLastYear']
# Out:
# 55      0
# 96      0
# 104     0
# 144     0
# 153     0
# 156     0
# 165     0
# 215     0
# 232     0
# 242     0
# 247     0
# 333     0
# 343     0
# 344     0
# 351     0
# 358     0
# 361     0
# 363     0
# 368     0
# 411     0
# 414     0
# 482     0
# 487     0
# 516     0
# 517     0
# 575     0
# 615     0
# 667     0
# 680     0
# 703     0
# 762     0
# 765     0
# 798     0
# 822     0
# 842     0
# 876     0
# 932     0
# 979     0
# 981     0
# 1002    0
# 1008    0
# 1034    0
# 1040    0
# 1068    0
# Name: TrainingTimesLastYear, dtype: int64

# %%
data.loc[data['TrainingTimesLastYear'] <1 , 'TrainingTimesLastYear'] = 3

# %%
data.loc[ data['TrainingTimesLastYear'] > 4 , 'TrainingTimesLastYear']
# Out:
# 10      5
# 13      6
# 27      5
# 31      5
# 59      6
#        ..
# 1158    5
# 1166    5
# 1184    5
# 1188    5
# 1193    5
# Name: TrainingTimesLastYear, Length: 144, dtype: int64

# %%
data.loc[ data['TrainingTimesLastYear'] > 4 , 'TrainingTimesLastYear'] = 3

# %%
data.ExperienceYearsAtThisCompany.median()
# Out:
# 5.0

# %%
data.loc[data['ExperienceYearsAtThisCompany'] > 20 , 'ExperienceYearsAtThisCompany']
# Out:
# 3       21
# 11      22
# 25      34
# 52      26
# 100     31
# 168     21
# 175     21
# 178     32
# 181     21
# 216     22
# 252     21
# 272     26
# 304     22
# 307     24
# 308     33
# 312     29
# 316     25
# 320     21
# 347     33
# 450     32
# 459     21
# 471     33
# 475     36
# 490     30
# 492     22
# 555     23
# 557     21
# 571     21
# 613     22
# 617     22
# 642     22
# 658     22
# 777     25
# 785     22
# 816     27
# 817     21
# 838     22
# 845     37
# 862     25
# 867     40
# 911     24
# 921     33
# 956     22
# 962     33
# 978     21
# 989     36
# 1015    22
# 1024    24
# 1027    21
# 1036    21
# 1086    25
# 1094    21
# 1104    29
# 1117    27
# 1156    31
# 1160    32
# Name: ExperienceYearsAtThisCompany, dtype: int64

# %%
data.loc[data['ExperienceYearsAtThisCompany'] > 20 , 'ExperienceYearsAtThisCompany'] = 5

# %%
data.ExperienceYearsInCurrentRole.median()
# Out:
# 3.0

# %%
data.loc[data['ExperienceYearsInCurrentRole'] > 14 , 'ExperienceYearsInCurrentRole']
# Out:
# 151     16
# 175     16
# 272     15
# 361     16
# 501     15
# 555     15
# 639     17
# 658     17
# 730     16
# 817     16
# 864     18
# 921     18
# 956     17
# 999     16
# 1109    15
# 1152    16
# Name: ExperienceYearsInCurrentRole, dtype: int64

# %%
data.loc[data['ExperienceYearsInCurrentRole'] > 14 , 'ExperienceYearsInCurrentRole'] = 3

# %%
data.YearsSinceLastPromotion.median()
# Out:
# 1.0

# %%
data.loc[data['YearsSinceLastPromotion'] > 7.5 , 'YearsSinceLastPromotion']
# Out:
# 3       12
# 11      11
# 100     14
# 130      8
# 132     11
#         ..
# 1152    11
# 1160    10
# 1181     8
# 1185    11
# 1189     9
# Name: YearsSinceLastPromotion, Length: 88, dtype: int64

# %%
data.loc[data['YearsSinceLastPromotion'] > 7.5 , 'YearsSinceLastPromotion'] = 1

# %%
data.YearsWithCurrManager.median()
# Out:
# 3.0

# %%
data.loc[data['YearsWithCurrManager'] > 14 , 'YearsWithCurrManager']
# Out:
# 25      16
# 72      17
# 126     17
# 283     17
# 320     17
# 655     16
# 785     17
# 864     15
# 888     15
# 956     15
# 1083    17
# Name: YearsWithCurrManager, dtype: int64

# %%
data.loc[data['YearsWithCurrManager'] > 14 , 'YearsWithCurrManager'] = 3

# %%
data.PerformanceRating.median()
# Out:
# 3.0

# %%
data.loc[data['PerformanceRating']  < 2.5  , 'PerformanceRating']
# Out:
# 132     2
# 162     2
# 164     2
# 165     2
# 169     2
#        ..
# 1152    2
# 1160    2
# 1162    2
# 1165    2
# 1199    2
# Name: PerformanceRating, Length: 194, dtype: int64

# %%
data.loc[data['PerformanceRating']  < 2.5  , 'PerformanceRating'] = 3

# %%
data.loc[data['PerformanceRating'] > 3.5 , 'PerformanceRating']
# Out:
# 2       4
# 5       4
# 12      4
# 18      4
# 25      4
#        ..
# 1180    4
# 1190    4
# 1191    4
# 1192    4
# 1195    4
# Name: PerformanceRating, Length: 132, dtype: int64

# %%
data.loc[data['PerformanceRating'] > 3.5 , 'PerformanceRating'] = 3

# %%
plt.figure(figsize=(20, 25))  # Set the figure size
num = 1  # Initialize subplot counter

for col in data.columns:  # Loop through all columns
    plt.subplot(5, 6, num)  # Create subplot in a 5x6 grid
    sns.boxplot(data=data, x=col)  # Draw boxplot for the column
    num += 1  # Increment subplot counter

plt.tight_layout()  # Adjust subplot spacing to avoid overlap
plt.show()  # Display all the boxplots

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# <b>Feature selection :</b> is a critical step in the data preprocessing pipeline, where the goal is to select the most important features from the original set of features in a dataset. By choosing only the relevant features, we aim to improve the performance of machine learning models. This process can help reduce complexity, improve model accuracy, and speed up the training process.

# %%
data.corr()  #check corrlation
# Out:
#                                    Age    Gender  EducationBackground  \
# Age                           1.000000 -0.040107            -0.055905
# Gender                       -0.040107  1.000000             0.009922
# EducationBackground          -0.055905  0.009922             1.000000
# MaritalStatus                -0.098368 -0.042169            -0.001097
# EmpDepartment                -0.000104 -0.010925            -0.026874
# EmpJobRole                   -0.037665  0.011332            -0.012325
# BusinessTravelFrequency       0.040579 -0.043608             0.012382
# DistanceFromHome              0.020937 -0.001507            -0.013919
# EmpEducationLevel             0.207313 -0.022960            -0.047978
# EmpEnvironmentSatisfaction    0.013814  0.000033             0.045028
# EmpHourlyRate                 0.062867  0.002218            -0.030234
# EmpJobInvolvement             0.027216  0.010949            -0.025505
# ...

# %%
## We have check correlation
plt.figure(figsize=(20, 25))  # Set figure size for the heatmap
sns.heatmap(data.corr(), annot=True, annot_kws={'size': 10})  # Plot correlation matrix with annotations
# Out:
# <Axes: >

# %%
x = data.drop("Attrition", axis=1)  # Features (all columns except 'Attrition')
y = data.Attrition                   # Target variable ('Attrition')

# %% [markdown]
# > * SMOTE (Synthetic Minority Over-sampling Technique) is a popular data preprocessing technique used to address class imbalance in classification problems.

# %%
from imblearn.over_sampling import SMOTE  # Import SMOTE to handle imbalanced datasets by oversampling minority class

# %%
smote = SMOTE(random_state=42)  # Initialize SMOTE with a fixed random state for reproducibility
x_resampled, y_resampled = smote.fit_resample(x, y)  # Apply SMOTE to balance the classes in the dataset

# %%
from imblearn.combine import SMOTETomek  # Import SMOTETomek for combined oversampling and cleaning

smt = SMOTETomek(random_state=42)  # Initialize SMOTETomek with a fixed random state
X_resampled, y_resampled = smt.fit_resample(x, y)  # Resample data to balance classes and remove noise

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_resampled,y_resampled,test_size=0.25,random_state=0)

# %%
# Importing various classification models from scikit-learn, CatBoost, and XGBoost
from sklearn.linear_model import LogisticRegression  # Logistic Regression, used for binary or multiclass classification
from sklearn.neighbors import KNeighborsClassifier  # K-Nearest Neighbors, a simple algorithm for classification based on proximity to neighbors
from sklearn.svm import SVC, LinearSVC  # Support Vector Classifier (SVC), used for classification tasks with high-dimensional data; LinearSVC is for linear decision boundaries
from sklearn.tree import DecisionTreeClassifier  # Decision Tree, a non-linear classifier that splits data based on feature values
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier  # Ensemble methods for improved performance:
# RandomForest (multiple decision trees), Gradient Boosting (sequential learning), and AdaBoost (boosting weak learners)
from sklearn.neural_network import MLPClassifier  # Multi-layer Perceptron (MLP), a type of neural network for classification
from catboost import CatBoostClassifier  # CatBoost, a gradient boosting algorithm designed for categorical data
from xgboost import XGBClassifier  # XGBoost, a highly efficient gradient boosting library for classification and regression tasks

# %%
# Importing classification evaluation metrics: confusion_matrix, accuracy_score, precision_score, 
# classification_report, f1_score, and roc_auc_score to assess model performance across various metrics.
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,classification_report,f1_score,roc_auc_score

# %%
# Defining a dictionary of classification models with their respective hyperparameters
models = {
    'Logistic Regression': LogisticRegression(),  # Logistic Regression with max iterations set to 1000
    'K-Nearest Neighbors': KNeighborsClassifier(),  # K-Nearest Neighbors classifier
    'Support Vector Machine': SVC(kernel='linear'),  # Support Vector Machine classifier
    'Linear SVM': LinearSVC(max_iter=10000),  # Linear Support Vector Machine with max iterations set to 10000
    'Decision Tree': DecisionTreeClassifier(),  # Decision Tree classifier
    'Random Forest': RandomForestClassifier(),  # Random Forest classifier (ensemble method)
    'Gradient Boosting': GradientBoostingClassifier(),  # Gradient Boosting classifier (ensemble method)
    'AdaBoost': AdaBoostClassifier(),  # AdaBoost classifier (ensemble method)
    'MLP Classifier': MLPClassifier(max_iter=1000),  # Multi-layer Perceptron classifier with max iterations set to 1000
    'CatBoost': CatBoostClassifier(),  # CatBoost classifier with verbosity turned off
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss')  # XGBoost classifier with settings for label encoding and evaluation metric
}

# %%
# Importing evaluation metrics for classification model performance
a = accuracy_score  # Accuracy metric
p = precision_score  # Precision metric
f = f1_score  # F1 score metric

# Function to evaluate model performance
def evaluate_model(true, predicted):
    accuracy_score = a(true, predicted)  # Calculate accuracy
    precision_score = p(true, predicted)  # Calculate precision
    f1_score_score = f(true, predicted)  # Calculate F1 score
    return accuracy_score, precision_score, f1_score_score  # Return evaluation metrics

# %%
# Initialize lists to store model names and their corresponding accuracy scores
model_list = []  # List to store model names
accuracy_score_list = []  # List to store model test accuracy scores
 
# Step 3: Loop through models and evaluate their performance
for model_name, model in models.items():
    model.fit(x_train, y_train)  # Train the model using the training data

    # Predictions on training and test sets
    y_train_pred = model.predict(x_train)  # Predict on training data
    y_test_pred = model.predict(x_test)  # Predict on test data

    # Evaluate model performance on both training and test sets
    model_train_accuracy_score, model_train_precision_score, model_train_f1_score = evaluate_model(y_train, y_train_pred)
    model_test_accuracy_score, model_test_precision_score, model_test_f1_score = evaluate_model(y_test, y_test_pred)

    # Print and store the results for both training and test sets
    print(f"Model: {model_name}")
    model_list.append(model_name)  # Store model name

    print('Model Performance for Training Set:')
    print("- Accuracy: {:.4f}".format(model_train_accuracy_score))
    print("- Precision: {:.4f}".format(model_train_precision_score))
    print("- F1 Score: {:.4f}".format(model_train_f1_score))
    print('----------------------------------')

    print('Model Performance for Test Set:')
    print("- Accuracy: {:.4f}".format(model_test_accuracy_score))
    print("- Precision: {:.4f}".format(model_test_precision_score))
    print("- F1 Score: {:.4f}".format(model_test_f1_score))

    accuracy_score_list.append(model_test_accuracy_score)  # Store test accuracy score
    
    

    print('='*40)  # Separator for readability
    print('\n')
# Out:
# Model: Logistic Regression
# Model Performance for Training Set:
# - Accuracy: 0.8269
# - Precision: 0.8184
# - F1 Score: 0.8305
# ----------------------------------
# Model Performance for Test Set:
# - Accuracy: 0.8219
# - Precision: 0.8279
# - F1 Score: 0.8162
# ...
#
#
# Model: K-Nearest Neighbors
# Model Performance for Training Set:
# - Accuracy: 0.8694
# - Precision: 0.7969
# - F1 Score: 0.8844
# ----------------------------------
# Model Performance for Test Set:
# - Accuracy: 0.8239
# - Precision: 0.7417
# - F1 Score: 0.8459
# ...
#
#
# Model: Support Vector Machine
# Model Performance for Training Set:
# - Accuracy: 0.8334
# - Precision: 0.8306
# - F1 Score: 0.8354
# ----------------------------------
# Model Performance for Test Set:
# - Accuracy: 0.8337
# - Precision: 0.8374
# - F1 Score: 0.8290
# ...
#
#
# Model: Linear SVM
# Model Performance for Training Set:
# - Accuracy: 0.8276
# - Precision: 0.8186
# - F1 Score: 0.8312
# ----------------------------------
# ...

# %%
# Create a DataFrame to store the model names and their corresponding accuracy scores, 
# and sort the results in descending order based on the accuracy score
result = pd.DataFrame(list(zip(model_list, accuracy_score_list)), columns=['Model Name', 'Accuracy_score']).sort_values(by=["Accuracy_score"],ascending=False)

# %%
result
# Out:
#                 Model Name  Accuracy_score
# 9                 CatBoost        0.925636
# 10                 XGBoost        0.923679
# 5            Random Forest        0.906067
# 6        Gradient Boosting        0.890411
# 8           MLP Classifier        0.878669
# 7                 AdaBoost        0.847358
# 2   Support Vector Machine        0.833659
# 3               Linear SVM        0.833659
# 1      K-Nearest Neighbors        0.823875
# 0      Logistic Regression        0.821918
# 4            Decision Tree        0.821918

# %%
best_row = result.loc[result['Accuracy_score'].idxmax()]
# Extract model name
best_model_name = best_row['Model Name']
print(f"Best model: {best_model_name}")

# Get the corresponding trained model from your models dictionary
best_model = models[best_model_name]
# Out:
# Best model: CatBoost

# %%
plt.figure(figsize=(10, 6)) # plotting using matplotlib
num = 0
for i in result :
    if num <= 7:
        a = sns.barplot(x='Model Name', y='Accuracy_score', data=result,palette='viridis')
        plt.title('R² Score Comparison of Models') # plotting using matplotlib
        plt.xlabel('Model Name') # plotting using matplotlib
        plt.ylabel('Accuracy score') # plotting using matplotlib
        # plt.ylim(0, 1.1) # plotting using matplotlib
        plt.xticks(rotation=90) # plotting using matplotlib
        
        for index,value in enumerate(result['Accuracy_score']):
            a.text(index,value + 0.02 , f'{value:.2f}',ha='center')

        num += 1

plt.tight_layout() # plotting using matplotlib
plt.show() # plotting using matplotlib

# %% [markdown]
# ## Model Comparision Report

# %% [markdown]
# * I have used total 10 Algorithm like 'XGBoost', 'CatBoost', 'Random Forest', 'MLP Classifier','Gradient Boosting', 'AdaBoost', 'Decision Tree',
#  'Support Vector Machine', 'Linear SVM', 'K-Nearest Neighbors','Logistic Regression'
# * Best Performing Model:- The CatBoost - 0.93 , XGBoost - 0.92 ,Random Forest - 0.90  the highest accuracy indicating superior performance in the dataset.
# * Moderate Performance:- Models such as MLPClassifier, Gradient Boosting, AdaBoost, Decision Tree,Support Vector Machine,LinearSVM,KNearestNeighbors,
#   LogisticRegression show comparable accuracy around 0.82 to 0.89 demonstrating moderate performance.

# %% [markdown]
# ##  Insights & Recommendations
#
# ###  Strengths
# - High job satisfaction
# - Long tenure at the company
# - Frequent training sessions attended
# - Strong relationship with current manager
# - Positive work-life balance
#
# ###  Risks
# - Low job involvement
# - No recent promotion (stagnation)
# - Long distance from home to office
# - Low environment or relationship satisfaction
# - Limited learning and growth opportunities
#
# ###  Recommended Actions
# - Provide personalized growth opportunities (e.g., skill-building projects, promotions)
# - Offer flexible travel arrangements or remote work options
# - Assign a mentor for career guidance and support
# - Conduct regular 1-on-1 feedback and development sessions
# - Initiate employee engagement programs to boost morale and involvement

# %%
import pickle                             #Importing the pickle module
with open('best_model.pkl', 'wb') as file:
    pickle.dump(best_model, file)                                         #save it to the file

# %%
with open("best_model.pkl","rb") as f:   #Open the file "best_model.pkl" in read-binary mode
    model=pickle.load(f)

# %%
model
